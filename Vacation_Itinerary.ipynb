# %%
import pandas as pd
import numpy as np
import requests
import gmaps
from config_g_key import key
gmaps.configure(api_key=key)

# %%
vacay = pd.read_csv("WeatherPy_vacation.csv")
vacay.head()
# Out:
#    City_ID          City Country Max Temp Current Description    Lat     Lng  \
# 0        9          Hilo      US     80.6     overcast clouds  19.73 -155.09
# 1       11  Luis Correia      BR    77.77       broken clouds  -2.88  -41.67
# 2       19         Kapaa      US     84.2       broken clouds  22.08 -159.32
# 3       20  Ponta Do Sol      PT     75.2       broken clouds  32.67  -17.10
# 4       26        Atuona      PF    78.69          light rain  -9.80 -139.03
#
#                                Hotel Name
# 0                     Hilo Hawaiian Hotel
# 1                         Hotel Amarração
# 2  Sheraton Kauai Resort at Coconut Beach
# 3                          Hotel do Campo
# 4                             Villa Enata

# %%
# Using the template add the city name, the country code, the weather description and maximum temperature for the city.
template = """

Hotel Name
{Hotel Name}

City
{City}
Country
{Country}
Weather Description
{Current Description}

Max Temp
{Max Temp} °F


"""

# Get the data from each row and add it to the formatting template and store the data in a list.
hotel_info = [template.format(**row) for index, row in vacay.iterrows()]

# Get the latitude and longitude from each row and store in a new DataFrame.
locations = vacay[["Lat", "Lng"]]

# %%
vacation_start = vacay.loc[vacay['City'] == 'Carson City']
vacation_end = vacay.loc[vacay['City'] == 'Carson City']
vacation_stop1 = vacay.loc[vacay['City'] == 'Half Moon Bay']
vacation_stop2 = vacay.loc[vacay['City'] == 'Ukiah'] 
vacation_stop3 = vacay.loc[vacay['City'] == 'Laguna'] 
vacation_stop3
# Out:
#      City_ID    City Country            Max Temp Current Description     Lat  \
# 99       371  Laguna      US                  84               smoke   38.42
# 371      371  Laguna      US  2020-08-21 2:25:09               38.42 -121.42
#
#         Lng                                         Hotel Name
# 99  -121.42  Holiday Inn Express & Suites Elk Grove Central...
# 371   84.00                                                 37

# %%
start = vacation_start.iloc[0,5:7].to_numpy()
end = vacation_end.iloc[0,5:7].to_numpy()
stop1 = vacation_stop1.iloc[0,5:7].to_numpy()
stop2 = vacation_stop2.iloc[0,5:7].to_numpy()
stop3 = vacation_stop3.iloc[0,5:7].to_numpy()

start
# Out:
# array([39.16, -119.77], dtype=object)

# %%
fig = gmaps.figure(center=(38, -122), zoom_level = 7)
carson_city = start
half_moon_bay = stop1
Ukiah = stop2
Laguna = stop3 
roadtrip = gmaps.directions_layer(carson_city, carson_city, 
                                  waypoints=[half_moon_bay, Ukiah, Laguna],
                                  travel_mode="DRIVING")

# %%
# To create a marker layer map between the four cities.

itinerary = pd.concat([vacation_start, vacation_stop1, 
                          vacation_stop2, vacation_stop3]
                         ,ignore_index=True)
itinerary
# Out:
#    City_ID           City Country            Max Temp Current Description  \
# 0      240    Carson City      US                  86           clear sky
# 1      240    Carson City      US  2020-08-21 2:22:07               39.16
# 2      389  Half Moon Bay      US                75.2                mist
# 3      389  Half Moon Bay      US  2020-08-21 2:23:49               37.46
# 4      435          Ukiah      US                82.4           clear sky
# 5      435          Ukiah      US  2020-08-21 2:25:18               39.15
# 6      371         Laguna      US                  84               smoke
# 7      371         Laguna      US  2020-08-21 2:25:09               38.42
#
#       Lat     Lng                                         Hotel Name
# 0   39.16 -119.77                  Courtyard by Marriott Carson City
# 1 -119.77   86.00                                                 15
# 2   37.46 -122.43                    The Ritz-Carlton, Half Moon Bay
# ...

# %%
# Using the template add city name, the country code, the weather description and maximum temperature for the city. 
new_template = """

Hotel Name
{Hotel Name}

City
{City}
Country
{Country}
Weather Description
{Current Description}

Max Temp
{Max Temp} °F


"""

# Get the data from each row and add it to the formatting template and store the data in a list.
hotel_info = [new_template.format(**row) for index, row in itinerary_df.iterrows()]

# Get the latitude and longitude from each row and store in a new DataFrame.
locations = itinerary[["Lat", "Lng"]]

# %%
# Add a marker layer for each city to the map.
marker_layer = gmaps.marker_layer(locations, info_box_content=hotel_info)
# fig.add_layer(marker_layer)
fig.add_layer(roadtrip)

# Display the figure
fig
# Out:
# ---------------------------------------------------------------------------
# InvalidPointException                     Traceback (most recent call last)
# <ipython-input-66-1fca9105bc2a> in <module>
#       1 # Add a marker layer for each city to the map.
# ----> 2 marker_layer = gmaps.marker_layer(locations, info_box_content=hotel_info)
#       3 # fig.add_layer(marker_layer)
#       4 fig.add_layer(roadtrip)
#       5
#
# ~\anaconda3\lib\site-packages\gmaps\marker.py in marker_layer(locations, hover_text, label, info_box_content, display_info_box)
#     553     marker_options = _marker_layer_options(
#     554         locations, hover_text, label, info_box_content, display_info_box)
# --> 555     markers = [Marker(**option) for option in marker_options]
#     556     return Markers(markers=markers)
#
# ~\anaconda3\lib\site-packages\gmaps\marker.py in <listcomp>(.0)
#     553     marker_options = _marker_layer_options(
# ...
